# %%
print("Read 10 Numbers :") 
counter=0 
sum=0 
while True: 
    number=float(input("Read number")) 
    if number<0: 
        print("can not Read Negative Number :") 
        continue 
    if number==0: 
        break 
    if number%2==0: 
        sum+=number 
    counter+=1 
    if counter==10: 
        break 
print("Sum of Even Numbers = ",sum)
# Out:
# Read 10 Numbers :
# Read number 1
# Read number 2
# Read number 3
# Read number 4
# Read number 5
# Read number 6
# Read number 7
# Read number 8
# Read number 9
# Read number 10
# Sum of Even Numbers =  30.0

# %%
print("Read  Number to Generate Multiplication Tabel :") 
number=int(input("Read number")) 
for x in range(1,number+1,1): 
    if x==3: 
        continue 
    product=x*12 
    if product >= 50: 
        break 
    print(x," x "," 12 "," = ",(x*12))
# Out:
# Read  Number to Generate Multiplication Tabel :
# Read number 5
# 1  x   12   =  12
# 2  x   12   =  24
# 4  x   12   =  48

# %%
counter=1 
while True: 
    number=int(input("Guess number")) 
    if number >=1 and number <=20: 
        print ("Guess Correctly : in Attempts :",counter) 
        break 
    else: 
        counter+=1 
        print("Error Guess and Total Attempts Number = ",counter) 
        continue
# Out:
# Guess number 4
# Guess Correctly : in Attempts : 1

# %%
counter=0 
number=int(input("Enter Number :")) 
for x in range(1,number + 1 , 1): 
    if number >50: 
        print("Stop Counting ") 
        break 
    if x %4==0: 
        counter+=1 
    if x %8==0: 
        continue 
print("Number Divided by 4 = ",counter)
# Out:
# Enter Number : 7
# Number Divided by 4 =  1

# %%
for i in range(1, 6):           
    for j in range(1, i+1):     
        if j == 3: 
            continue            
        if i * j > 6: 
            break               
        print(j, end=" ")       
    print()
# Out:
# 1
# 1 2
# 1 2
# 1
# 1
